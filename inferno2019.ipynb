# %%
import pandas as pd

df = pd.read_csv('.\\data\\2019\\infracoes_2019_06.csv', sep=',')

# %%
df2=pd.read_csv('.\\data\\2017\\2017_dez.csv', sep=',', encoding='ISO-8859-1')

# %%
df2.head()
# Out:
#   dat_infracao tip_abordagem ind_assinou_auto ind_veiculo_estrangeiro  \
# 0   2017-12-01             S              NaN                       N
# 1   2017-12-01             S              NaN                       N
# 2   2017-12-01             S              NaN                       N
# 3   2017-12-01             S              NaN                       N
# 4   2017-12-01             S              NaN                       N
#
#   ind_sentido_trafego uf_placa uf_infracao  num_br_infracao  num_km_infracao  \
# 0                 NaN       MG          MG              381              568
# 1                 NaN       MG          BA              324              619
# 2                 NaN       RJ          RJ              116              167
# 3                 NaN       SP          SP              116               65
# 4                 NaN       SP          SP              116              110
#
#         nom_municipio  ...  enquadramento data_inicio_vigencia  \
# ...

# %%
df['Código da Infração'].head(5)
# Out:
# 0    75790
# 1    66020
# 2    66020
# 3    72422
# 4    72422
# Name: Código da Infração, dtype: int64

# %%
df.head()
# Out:
#        numero_auto dat_infracao tip_abordagem ind_assinou_auto  \
# 0  1286f7f761e5c02   2019-06-21             C                S
# 1  20cc8a77dd9734f   2019-06-14             C                N
# 2  2219bf224677c16   2019-06-14             S                N
# 3  e00c86bc5dc9134   2019-06-25             S                N
# 4  620c964b82bd31a   2019-06-25             S                N
#
#   ind_veiculo_estrangeiro ind_sentido_trafego uf_placa uf_infracao  \
# 0                       N                   C       MG          MG
# 1                       N                   C       RS          RS
# 2                       N                   C       RS          RS
# 3                       N                   D       MG          MG
# 4                       N                   D       MG          MG
#
#    num_br_infracao  num_km_infracao  ...  \
# 0              364              140  ...
# 1              290              124  ...
# 2              290              124  ...
# ...

# %%
df.dat_infracao
# Out:
# 0         2019-06-21
# 1         2019-06-14
# 2         2019-06-14
# 3         2019-06-25
# 4         2019-06-25
#              ...
# 492836    2019-06-30
# 492837    2019-06-30
# 492838    2019-06-30
# 492839    2019-06-30
# 492840    2019-06-30
# Name: dat_infracao, Length: 492841, dtype: object

# %%
df2.head(1)
# Out:
#   dat_infracao tip_abordagem ind_assinou_auto ind_veiculo_estrangeiro  \
# 0   2009-01-01             C              NaN                       N
#
#   ind_sentido_trafego uf_placa uf_infracao  num_br_infracao  num_km_infracao  \
# 0                   C       TO          TO              153              132
#
#   nom_municipio                                descricao_abreviada  \
# 0     ARAGUAINA  Dirigir veículo sem possuir CNH ou Permissão p...
#
#   enquadramento data_inicio_vigencia data_fim_vigencia  med_realizada  \
# 0         162 I           2000-01-01        2016-10-31            NaN
#
#    med_considerada  exc_verificado     especie nome_veiculo_marca  \
# 0              NaN             NaN  PASSAGEIRO              OUTRA
#
#   nom_modelo_veiculo
# 0      TRAXX JL500 2

# %%
df2 = pd.read_csv('.\\data\\2009\\2009_jan_fev.csv')
