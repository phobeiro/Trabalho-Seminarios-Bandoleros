# %%
import pandas as pd

df = pd.read_csv('data\csv\infracoes_2010.csv', sep=';')

# %%
len(df)
# Out:
# 3038357

# %%
df[['med_realizada','med_considerada']].loc[df.med_considerada.notnull()]
# Out:
#          med_realizada  med_considerada
# 1                 97.0             90.0
# 2                100.0             93.0
# 3                 53.0             46.0
# 5                105.0             98.0
# 6                 92.0             85.0
# ...                ...              ...
# 3038342          100.0             93.0
# 3038343           88.0             81.0
# 3038344           88.0             81.0
# 3038351           99.0             92.0
# 3038353          110.0            102.0
#
# [1312171 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['dat_infracao', 'tip_abordagem', 'ind_assinou_auto',
#        'ind_veiculo_estrangeiro', 'ind_sentido_trafego', 'uf_placa',
#        'uf_infracao', 'num_br_infracao', 'num_km_infracao', 'nom_municipio',
#        'descricao_abreviada', 'enquadramento', 'data_inicio_vigencia',
#        'data_fim_vigencia', 'med_realizada', 'med_considerada',
#        'exc_verificado', 'especie', 'nome_veiculo_marca', 'mes_infracao',
#        'ano_infracao'],
#       dtype='object')

# %%
for i in df.descricao_abreviada.unique():
    print(i)
# Out:
# Conduzir o veículo que não esteja registrado
# Transitar em velocidade superior à máxima permitida em até 20%
# Conduzir o veículo c/ equip do sistema de iluminação e de sinalização alterados
# Conduzir veículo sem os documentos de porte obrigatório referidos no CTB
# Conduzir o veículo transportando passageiros em compartimento de carga
# Conduzir motocicleta, motoneta e ciclomotor sem capacete de segurança
# Transitar em velocidade superior à máxima permitida em mais de 20% até 50%
# Transitar em desacordo c/ autorização expedida p/veículo c/ dimensões excedentes
# Executar operação de retorno em locais proibidos pela sinalização
# Dirigir sob a influência de álcool
# Deixar o passageiro de usar o cinto segurança
# Estacionar nos acostamentos
# Estacionar ao lado ou sobre gramado ou jardim público
# Ultrapassar pela contramão nas pontes
# Transitar com o veículo com lotação excedente
# Conduzir o veículo com equipamento obrigatório ineficiente ou inoperante
# ...
